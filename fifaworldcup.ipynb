# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df=pd.read_csv("csvSamples/players_22.csv")
df.head(10)
# Out:
# C:\Users\USER-PC\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8     192448  https://sofifa.com/player/192448/marc-andre-te...
# 9     202126  https://sofifa.com/player/202126/harry-kane/22...
#
# ...

# %%
mydata=pd.read_csv('csvSamples/zillow.csv')
mydata.head()
mydata.describe(include="all")
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    20 non-null     int64
#  1    "Living Space (sq ft)"  20 non-null     int64
#  2    "Beds"                  20 non-null     int64
#  3    "Baths"                 20 non-null     float64
#  4    "Zip"                   20 non-null     int64
#  5    "Year"                  20 non-null     int64
#  6    "List Price ($)"        20 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 1.2 KB

# %%
#del df['player_url'] #deletes the column selected in index
#df.head(20)

del df['club_logo_url']
df.head(6)
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1     188545     R. Lewandowski                   Robert Lewandowski
# 2      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
# 5     200389           J. Oblak                            Jan Oblak
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93   78000000.0  320000.0   34
# 1               ST       92         92  119500000.0  270000.0   32
# 2           ST, LW       91         91   45000000.0  270000.0   36
# 3          LW, CAM       91         91  129000000.0  270000.0   29
# 4          CM, CAM       91         91  125500000.0  350000.0   30
# 5               GK       91         93  112000000.0  130000.0   28
#
# ...

# %%
plt.figure(figsize=(16,32))
sns.countplot(y=df.potential , palette="Set2")
# Out:
# <AxesSubplot:xlabel='count', ylabel='potential'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="age", data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>
